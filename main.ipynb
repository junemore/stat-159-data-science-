# %% [markdown]
# # An analysis of the State of the Union speeches
#
# **Authors: Yuanfeng Hu, Aiting(Kelly) Kuang, Yuening Zhu**

# %% [markdown]
# ## Abstract
#
# ***In this notebook, we will include some results of our research. Our research includes a wide range of field from data analysis, historical research and press search. Our report will be consist of Four Parts.***
#
#
# *** Most Common Word Used by President Barak Obama in SOTU Address***
#
# ***Difference in Unique Number of words***
#
# ***Declining Reading Level of SOTU Addresses***
#
# ***45 Terms of Presidencies and 42 Unique SOTU Address?***

# %% [markdown]
# ## Content

# %% [markdown]
# *** Most Common Word Used by President Barak Obama in SOTU Address***
#
#         The notebook number five has given us an opportunity to explore things that we are interested in. John F. Kennedy is said to be one of the most charismatic President whose speeches are both convincing and motivational. However, the golden era of President Kennedy has already passed. The most inspiration public speaker in our mind must goes to President Barak Obama. In this notebook, we will explore some characteristic of his speech in all his SOTU address.

# %% [markdown]
# ***Difference in Unique Number of words***
#
#         While we are trying to find unique number of words in each speeches, this process is much more harder then we initially though. There are many factors need to be taken into consideration: capitalization, white-space, punctuation, number and digits, and special symbol. We have to filter out all non-necessary information; otherwise the final number will not be close.
#         We have explored many methods to figure out this problem. We tried two different method: using set() function or using Counter() function. We also tried adjusting for capitalization, or single-character word and all other factors. There has been tons of trial and error, but the number is still bit of from the given number.
#         The reason why our number is slightly different from the given number is that there must another factor that we had missed. Perhaps, we could also tried tokenized each speech by sentence first, then tokenize each sentence by word, and then create a set of list. (We actually also tried this way and taken consideration of other factors, but still couldn't get the same number)
#         Eventually, we decide to use Counter function combine with tokenize function. This way, the number is closest to the number given by Professor. In the end, after rigorous effort, we stand strong behind our number. And we look forward to see the original code, which should blow our mind of which factor we have missed.

# %% [markdown]
# ***Declining Reading Level of SOTU Addresses***

# %%
from IPython.display import Image
PATH = "fig/speech_changes.png"
PATH2 = "fig/speech_characteristics.png"
Image(filename = PATH)

# %%
Image(filename = PATH2)

# %% [markdown]
#         As we complete our analysis of the characteristic of speech, we manage to generate some visualization. As a result, we are able to extrapolate some information about general trend in SOT addresses.
#         Firstly, we noticed that he graph of number of sentences and number of words seems to have a positive upward trend. This COULD suggest that Presidents are using more and more words and sentences in the SOTU address. It also means that the duration of State of Union address is generally getting longer as time approaches present. Secondly, the graph of vocabulary size per word, average sentence length, average word length and fraction of stop words seems to have negative downward trend. This could suggest that the President were choosing to use less complicate words and sentence. In other word, President tries to keep the language plain and simple, as time goes to present.
#         In order to further confirm out extrapolation, we were able to find a article only by Priceonomics. The title of the article is “The Reading Level of the State of Union Address is in Decline.”
#         The main idea of the article claims that: United States Presidents have made their speeches simpler over time.  The author uses an algorithm to calculate socres for each Presidents speeches based on the idea that “a simple terms, writing with longer sentences and bigger words yields a higher score (grade level) than simplistic writing.” The result is informing: with President James madison ranked the highest out of in the scores out of 42 President and President Obama rank the lowest in the score. It confirms our belief that earlier President tends to use hard, more complicate word and sentence while recent President tends to use simple languages.
#         The trend of the SOTU address should not imply that the quality of speeches is getting inferior or worse. A plain and simple speech is much more appealing and informing to the general public. Same idea is also confirmed in the article: “For instance, John F. Kennedy and Franklin D. Roosevelt, who respectively rank 30th and 31st on our reading level list, are both considered to be among the best speakers in history by Presidential scholars.”
#         One more fun fact mentioned in the article is that “Still, if this downward trend continues at the same rate, State of the Union speeches will be targeted towards kindergarteners (reading level 0) by the year 2243.” The trend still seems to be continue with our sitting President, Donald Trump, who is not included in the analysis in the article. But, it is somewhat true that, Trump tends to use extremely simple language not only in his SOTU address, but also in his daily communication with the public and other movement agencies

# %% [markdown]
# ***45 terms of Presidencies and 42 Presidents delievered SOTU ?***
#
#         While we are working through the notebook 1, we notice some discrepancies in the results. In order to figure out what really happens, we did some research and we found something really interesting.
#         As none of us are experts in U.S history, some of the discrepancies are just confusing and makes us scratch our head. For example, why is that the sitting President, President Donald Trump, is the 45th President, but there have only been 42 unique State of Union (SOTU) address. Let’s put this into a formal question, why is that only 42 Presidents delivered the State of Union address while there are 45 terms of Presidencies?  We started with the though that perhaps there were no SOTU address delivered during the time of World Wars. However, after checking that there are indeed SOTU address delivered during 1914 to 1918(WWI) and 1939 to 1945(WWII). Our second thought is that perhaps some President did not deliver SOTU address. This thought had not been our initial guess since the Constitution requires the President to periodically give Congress information on the "state of the union", thus making us though that none of the President would skip. However, our research suggests otherwise. It turns out that there are two presidents who never delivered an Annual Message or State of the Union Address. William Henry Harrison and James Garfield both died before they had the chance to deliver one. Harrison passed away from pneumonia in 1841 and Garfield died from an assassin’s bullet in 1881.
#         Minus the two Presidents who didn’t deliver SOTU address, we are still one number shy from the 42 unique speeches. This problem turns out to be extremely confusing. As a result, we decided to cross reference the list of Presidents in our txt file and resource from Internet. Surprisingly, we found the discrepancies. The address of index 103 is the President Benjamin Harrison last address on 1892, and the address of index 104 is President William McKinley first address on 1898. President Grover Cleveland second term is from 1893 to 1897, which is skipped in the data txt. Grover Cleveland stands alone in American history as the only President to serve non-consecutive terms. He was the 22nd and 24th President of the United States. Due to these non-consecutive terms, he addresses only count as 1 unique address.
#         Now, we are finally able to answer that question. 45 terms of Presidency minus the two Presidents who didn’t deliver and the one President, who served non-consecutive terms, we can now understand the discrepancies. This discrepancy also explains the large gap in the plot of time in p1, since s. (The data on second term of President Grove Cleveland (1893-1897) wasn't include in the txt)
